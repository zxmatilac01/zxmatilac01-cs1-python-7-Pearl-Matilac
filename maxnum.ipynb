# %% [markdown]
# <a href="https://colab.research.google.com/github/zxmatilac01/zxmatilac01-cs1-python-7-Pearl-Matilac/blob/main/maxnum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Enter 3 Numbers")
num1 = int(input("Enter First Number: "))
num2 = int(input("Enter Second Number: "))
num3 = int(input("Enter Third Number: "))

#compare the numbers
if num1 > num2:
  print("The Biggest Number Is: ", num1)
elif num2 > num1:
  print("The Biggest Number Is: ", num2)
elif num3 > num2:
  print("The Biggest Number Is: ", num3)
# Out:
# Enter 3 Numbers
# Enter First Number: 7
# Enter Second Number: 5
# Enter Third Number: 6
# The Biggest Number Is:  7
